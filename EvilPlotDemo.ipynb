// %% [markdown]
// Examples from https://nbviewer.jupyter.org/github/almond-sh/almond-examples/blob/master/notebooks/visualization/evilplot.ipynb

// %%
interp.repositories() ++= Seq(
  coursierapi.MavenRepository.of("https://dl.bintray.com/cibotech/public")
)

// %%
import $ivy.`com.cibo::evilplot-repl:0.6.3`

def showPlot(plot: com.cibo.evilplot.geometry.Drawable) =
  Image.fromRenderedImage(plot.asBufferedImage, format=Image.PNG)
// Out:
// import $ivy.$
//
//
// defined function showPlot

// %%
import com.cibo.evilplot._
import com.cibo.evilplot.plot._
import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
import com.cibo.evilplot.numeric.Point

val data = Seq.tabulate(100) { i =>
  Point(i.toDouble, scala.util.Random.nextDouble())
}

showPlot(ScatterPlot(data).render())
// Out:
// import com.cibo.evilplot._
//
// import com.cibo.evilplot.plot._
//
// import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
//
// import com.cibo.evilplot.numeric.Point
//
//
// data: Seq[Point] = List(
//   Point(0.0, 0.30395864692096997),
//   Point(1.0, 0.9857897793274956),
//   Point(2.0, 0.908977624855535),
//   Point(3.0, 0.9985459904303475),
//   Point(4.0, 0.5462325031549319),
//   Point(5.0, 0.16739289057791595),
//   Point(6.0, 0.5873047944221476),
//   Point(7.0, 0.5321782527363309),
//   Point(8.0, 0.7275986248190138),
//   Point(9.0, 0.6710143519905992),
//   Point(10.0, 0.9453655291670584),
//   Point(11.0, 0.2262249980106228),
//   Point(12.0, 0.23459749482026282),
//   Point(13.0, 0.8825260924822614),
//   Point(14.0, 0.3838105317530024),
//   Point(15.0, 0.23736396491598288),
//   Point(16.0, 0.6994540862009075),
//   Point(17.0, 0.19294586203854358),
//   Point(18.0, 0.8820727511678239),
//   Point(19.0, 0.02656904550768857),
//   Point(20.0, 0.9126420170807756),
//   Point(21.0, 0.6691811661830187),
//   Point(22.0, 0.7185529296550945),
//   Point(23.0, 0.341095834630188),
//   Point(24.0, 0.0020042914111561005),
//   Point(25.0, 0.09848482552670279),
//   Point(26.0, 0.13218185987091025),
//   Point(27.0, 0.9653357676835657),
//   Point(28.0, 0.6462836451922972),
//   Point(29.0, 0.7342893484852294),
//   Point(30.0, 0.15854405256249327),
//   Point(31.0, 0.6780691033843619),
//   Point(32.0, 0.34189179504554),
//   Point(33.0, 0.9236265380228122),
//   Point(34.0, 0.8903494547062082),
//   Point(35.0, 0.09681145814823744),
//   Point(36.0, 0.773973359313296),
//   Point(37.0, 0.6801272917530956),
// ...

// %%
import com.cibo.evilplot.plot._
import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
import com.cibo.evilplot.numeric.Point

val data = Seq.tabulate(100) { i =>
  Point(i.toDouble, scala.util.Random.nextDouble())
}

val plot = ScatterPlot(data)
  .xAxis()
  .yAxis()
  .frame()
  .xLabel("x")
  .yLabel("y")
  .render()

showPlot(plot)
// Out:
// import com.cibo.evilplot.plot._
//
// import com.cibo.evilplot.plot.aesthetics.DefaultTheme._
//
// import com.cibo.evilplot.numeric.Point
//
//
// data: Seq[Point] = List(
//   Point(0.0, 0.7957402946023847),
//   Point(1.0, 0.2260463203557448),
//   Point(2.0, 0.6425611934557395),
//   Point(3.0, 0.22501818306668042),
//   Point(4.0, 0.277197562851455),
//   Point(5.0, 0.8764794388576732),
//   Point(6.0, 0.7696047091873328),
//   Point(7.0, 0.09012929747676945),
//   Point(8.0, 0.7493267762848762),
//   Point(9.0, 0.7054017795211743),
//   Point(10.0, 0.19007369778546712),
//   Point(11.0, 0.30103673622670357),
//   Point(12.0, 0.6879771718084822),
//   Point(13.0, 0.753099791835737),
//   Point(14.0, 0.20013589666468767),
//   Point(15.0, 0.057616438903579925),
//   Point(16.0, 0.32322321693743317),
//   Point(17.0, 0.5133649867881936),
//   Point(18.0, 0.2397247508639755),
//   Point(19.0, 0.7322953968040278),
//   Point(20.0, 0.6302758125048056),
//   Point(21.0, 0.3995422286705492),
//   Point(22.0, 0.09868006068588764),
//   Point(23.0, 0.9227475167378703),
//   Point(24.0, 0.9512386795447721),
//   Point(25.0, 0.4126892426309976),
//   Point(26.0, 0.7493547000610833),
//   Point(27.0, 0.035939480015148795),
//   Point(28.0, 0.6649766293360839),
//   Point(29.0, 0.027991200968831342),
//   Point(30.0, 0.8289108050579832),
//   Point(31.0, 0.29515886273222924),
//   Point(32.0, 0.10458915336938779),
//   Point(33.0, 0.9493631137451898),
//   Point(34.0, 0.8423811203796029),
//   Point(35.0, 0.5860706472081033),
//   Point(36.0, 0.4854592418871354),
//   Point(37.0, 0.047212184150547065),
// ...
// plot: geometry.Drawable = Group(
//   Vector(
//     Translate(
//       StrokeStyle(
//         Group(
//           Vector(
//             Translate(Rotate(Line(549.0, 1.0), 90.0), -0.5000000000000168, 0.0),
//             Translate(Line(732.0126953125, 1.0), 0.0, 548.5)
//           )
//         ),
//         HSLA(0.0, 0.0, 12.0, 1.0)
//       ),
//       67.9873046875,
//       0.0
//     ),
//     Translate(
//       Resize(
//         Group(
//           Vector(
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0)),
//               0.0,
//               112.13857826329081
//             ),
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0)),
//               7.320126953125,
//               424.9005701246961
//             ),
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0)),
//               14.64025390625,
//               196.23390479279902
//             ),
//             Translate(
//               Style(Translate(Disc(4.0), -4.0, -4.0), HSLA(0.0, 0.0, 12.0, 1.0))...
